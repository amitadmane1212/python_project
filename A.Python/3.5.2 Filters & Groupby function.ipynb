# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies_data.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df[df['star_rating']>9]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df[df['star_rating']<7.5]
# Out:
#      star_rating                                            title  \
# 930          7.4                                  Man on the Moon
# 931          7.4                                     Mean Streets
# 932          7.4        Harry Potter and the Order of the Phoenix
# 933          7.4                                      Beetlejuice
# 934          7.4                             Crazy, Stupid, Love.
# 935          7.4                                        Excalibur
# 936          7.4                                        True Grit
# 937          7.4                                        Labyrinth
# 938          7.4                              Alice in Wonderland
# 939          7.4                                   Predestination
# 940          7.4                           Much Ado About Nothing
# 941          7.4                                 A Bridge Too Far
# 942          7.4                                  Raising Arizona
# ...

# %%
df.loc[np.where(df['star_rating']>9)]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# # And condition()

# %%
df[(df['star_rating']>9)&(df['duration']>150)]
# Out:
#    star_rating                   title content_rating  genre  duration  \
# 1          9.2           The Godfather              R  Crime       175
# 2          9.1  The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
df[(df['star_rating']>8)&(df['duration']>150)&(df['content_rating']=='R')]
# Out:
#      star_rating                                 title content_rating  \
# 1            9.2                         The Godfather              R
# 2            9.1                The Godfather: Part II              R
# 4            8.9                          Pulp Fiction              R
# 8            8.9                      Schindler's List              R
# 36           8.6                   Saving Private Ryan              R
# 40           8.5                        The Green Mile              R
# 44           8.5                             Gladiator              R
# 49           8.5                          The Departed              R
# 50           8.5                       Cinema Paradiso              R
# 51           8.5                        Apocalypse Now              R
# 59           8.5                      Django Unchained              R
# 78           8.4           Once Upon a Time in America              R
# ...

# %% [markdown]
# # OR condition()

# %%
df[(df['star_rating']>9)|(df['duration']>200)]
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 1            9.2                                  The Godfather
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
# ...

# %%
df[((df['star_rating']>9)&(df['content_rating']=='R'))|((df['genre']=='Adventure')&(df['duration']>200))]
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 1            9.2                                  The Godfather
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
#
# ...

# %% [markdown]
# # isin function()

# %%
list1 = ['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED']

df[df['content_rating'].isin(list1)]
df.loc[np.where(df['content_rating'].isin(list1))]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# # Not operator

# %%
df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
list1 = ['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED']
list2 = ['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
       'Comedy', 'Animation', 'Mystery', 'Horror']

df[~(df['content_rating'].isin(list1)|(df['genre'].isin(list2)))]
# Out:
#      star_rating                                title content_rating  \
# 210          8.1                                Laura       APPROVED
# 350          8.0                    Shadow of a Doubt       APPROVED
# 484          7.8        The Day the Earth Stood Still       APPROVED
# 497          7.8  Willy Wonka & the Chocolate Factory              G
#
#          genre  duration                                        actors_list
# 210  Film-Noir        88  [u'Gene Tierney', u'Dana Andrews', u'Clifton W...
# 350   Thriller       108  [u'Teresa Wright', u'Joseph Cotten', u'Macdona...
# 484     Sci-Fi        92  [u'Michael Rennie', u'Patricia Neal', u'Hugh M...
# 497     Family       100  [u'Gene Wilder', u'Jack Albertson', u'Peter Os...

# %% [markdown]
# # unique()

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df['content_rating'].unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %% [markdown]
# # nunique()

# %%
df['genre'].nunique()
# Out:
# 16

# %%
df['content_rating'].nunique()
# Out:
# 12

# %% [markdown]
# # value_counts()

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df[df['genre']=='Family']
# Out:
#      star_rating                                title content_rating   genre  \
# 468          7.9           E.T. the Extra-Terrestrial             PG  Family
# 497          7.8  Willy Wonka & the Chocolate Factory              G  Family
#
#      duration                                        actors_list
# 468       115  [u'Henry Thomas', u'Drew Barrymore', u'Peter C...
# 497       100  [u'Gene Wilder', u'Jack Albertson', u'Peter Os...

# %% [markdown]
# # groupby

# %%
df.groupby('genre')

# %%
from termcolor import colored
for genre,subdf in df.groupby('genre'):
    print(colored(genre,attrs=['bold']))
#     display(subdf)
# Out:
# Action
# Adventure
# Animation
# Biography
# Comedy
# Crime
# Drama
# Family
# Fantasy
# Film-Noir
# History
# Horror
# Mystery
# Sci-Fi
# Thriller
# Western

# %% [markdown]
# # getgroup()

# %%
df.groupby('genre').get_group('Comedy')
# Out:
#      star_rating                                              title  \
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 52           8.5                                 The Great Dictator
# ..           ...                                                ...
# 959          7.4                               Deconstructing Harry
# 960          7.4                                   The Way Way Back
# 962          7.4                                 Driving Miss Daisy
# 971          7.4                                 Death at a Funeral
# 974          7.4                                            Tootsie
#
#     content_rating   genre  duration  \
# 25           PG-13  Comedy       116
# 29          PASSED  Comedy        87
# ...

# %%
df.groupby(['genre','content_rating']).get_group(('Comedy','PG-13'))
# Out:
#      star_rating                                           title  \
# 25           8.6                               Life Is Beautiful
# 60           8.5                                        3 Idiots
# 314          8.0                         Crimes and Misdemeanors
# 356          8.0                                      The Artist
# 370          8.0                          Hannah and Her Sisters
# 459          7.9                        Ferris Bueller's Day Off
# 542          7.8                            (500) Days of Summer
# 578          7.8                              As Good as It Gets
# 622          7.7                                 The Dinner Game
# 639          7.7                                    Billy Elliot
# 667          7.7                               Midnight in Paris
# 696          7.7                           Stranger Than Fiction
# 735          7.6  The Naked Gun: From the Files of Police Squad!
# ...

# %% [markdown]
# # statistical functions on groupby

# %%
df.groupby('genre').sum()
# Out:
#            star_rating  duration
# genre
# Action          1072.3     17202
# Adventure        595.0     10113
# Animation        490.7      5989
# Biography        605.4     10152
# Comedy          1220.3     16786
# Crime            981.7     15165
# Drama           2196.9     35178
# Family            15.7       215
# Fantasy            7.7       112
# Film-Noir         24.1       292
# History            8.0        66
# Horror           226.4      2973
# Mystery          127.6      1850
# Sci-Fi            39.6       545
# Thriller          38.4       571
# Western           74.3      1230

# %%
df.groupby('genre').mean()
# Out:
#            star_rating    duration
# genre
# Action        7.884559  126.485294
# Adventure     7.933333  134.840000
# Animation     7.914516   96.596774
# Biography     7.862338  131.844156
# Comedy        7.822436  107.602564
# Crime         7.916935  122.298387
# Drama         7.902518  126.539568
# Family        7.850000  107.500000
# Fantasy       7.700000  112.000000
# Film-Noir     8.033333   97.333333
# History       8.000000   66.000000
# Horror        7.806897  102.517241
# Mystery       7.975000  115.625000
# Sci-Fi        7.920000  109.000000
# Thriller      7.680000  114.200000
# Western       8.255556  136.666667

# %%
df.groupby('genre')['duration'].mean().reset_index()
# Out:
#         genre    duration
# 0      Action  126.485294
# 1   Adventure  134.840000
# 2   Animation   96.596774
# 3   Biography  131.844156
# 4      Comedy  107.602564
# 5       Crime  122.298387
# 6       Drama  126.539568
# 7      Family  107.500000
# 8     Fantasy  112.000000
# 9   Film-Noir   97.333333
# 10    History   66.000000
# 11     Horror  102.517241
# 12    Mystery  115.625000
# 13     Sci-Fi  109.000000
# 14   Thriller  114.200000
# 15    Western  136.666667

# %%
df.groupby(['genre','content_rating'])['title'].count()
# Out:
# genre    content_rating
# Action   APPROVED          3
#          G                 1
#          GP                1
#          NOT RATED         4
#          PASSED            1
#                           ..
# Western  APPROVED          1
#          NOT RATED         2
#          PG                2
#          PG-13             1
#          R                 3
# Name: title, Length: 95, dtype: int64

# %%
df.groupby(['genre','content_rating'])['duration'].sum().reset_index().head(20)
# Out:
#         genre content_rating  duration
# 0      Action       APPROVED       430
# 1      Action              G       178
# 2      Action             GP       144
# 3      Action      NOT RATED       518
# 4      Action         PASSED        98
# 5      Action             PG      1317
# 6      Action          PG-13      5729
# 7      Action              R      8298
# 8      Action        UNRATED       332
# 9   Adventure       APPROVED       475
# 10  Adventure              G       324
# 11  Adventure      NOT RATED       566
# 12  Adventure         PASSED       102
# 13  Adventure             PG      2813
# 14  Adventure          PG-13      3310
# 15  Adventure              R      2123
# 16  Adventure        UNRATED       272
# 17  Animation       APPROVED       254
# 18  Animation              G      1863
# 19  Animation      NOT RATED       273

# %%
df.groupby('content_rating')['duration'].max().reset_index()
# Out:
#    content_rating  duration
# 0        APPROVED       220
# 1               G       238
# 2              GP       172
# 3           NC-17       179
# 4       NOT RATED       189
# 5          PASSED       172
# 6              PG       224
# 7           PG-13       242
# 8               R       229
# 9           TV-MA       131
# 10        UNRATED       207
# 11              X       136

# %% [markdown]
# # agg function in groupby`

# %%
df.groupby('content_rating')['star_rating'].agg((np.mean,np.median,np.sum,np.max,np.min)).reset_index()
# Out:
#    content_rating      mean  median     sum  amax  amin
# 0        APPROVED  8.027660     8.1   377.3   8.7   7.5
# 1               G  7.990625     8.0   255.7   8.6   7.4
# 2              GP  7.933333     8.0    23.8   8.1   7.7
# 3           NC-17  7.614286     7.6    53.3   7.9   7.4
# 4       NOT RATED  8.123077     8.2   528.0   8.9   7.5
# 5          PASSED  8.157143     8.1    57.1   8.6   7.7
# 6              PG  7.879675     7.8   969.2   8.8   7.4
# 7           PG-13  7.828571     7.8  1479.6   9.0   7.4
# 8               R  7.854783     7.8  3613.2   9.3   7.4
# 9           TV-MA  8.100000     8.1     8.1   8.1   8.1
# 10        UNRATED  7.994737     8.0   303.8   8.7   7.4
# 11              X  7.925000     7.9    31.7   8.4   7.5

# %%
df.groupby('content_rating')['genre'].agg(pd.Series.mode).reset_index()
# Out:
#    content_rating                           genre
# 0        APPROVED                           Drama
# 1               G                       Animation
# 2              GP     [Action, Biography, Comedy]
# 3           NC-17                           Drama
# 4       NOT RATED                           Drama
# 5          PASSED                          Comedy
# 6              PG              [Animation, Drama]
# 7           PG-13                           Drama
# 8               R                           Drama
# 9           TV-MA                           Drama
# 10        UNRATED                           Crime
# 11              X  [Comedy, Crime, Drama, Horror]

# %%
df.groupby('genre').agg({'star_rating':'mean','content_rating':'count'})
# Out:
#            star_rating  content_rating
# genre
# Action        7.884559             135
# Adventure     7.933333              74
# Animation     7.914516              62
# Biography     7.862338              76
# Comedy        7.822436             156
# Crime         7.916935             124
# Drama         7.902518             278
# Family        7.850000               2
# Fantasy       7.700000               1
# Film-Noir     8.033333               3
# History       8.000000               1
# Horror        7.806897              29
# Mystery       7.975000              16
# Sci-Fi        7.920000               5
# Thriller      7.680000               5
# Western       8.255556               9

# %% [markdown]
# # aggregate function()

# %%
df.groupby('genre').aggregate({'star_rating':'mean','content_rating':'count'})
# Out:
#            star_rating  content_rating
# genre
# Action        7.884559             135
# Adventure     7.933333              74
# Animation     7.914516              62
# Biography     7.862338              76
# Comedy        7.822436             156
# Crime         7.916935             124
# Drama         7.902518             278
# Family        7.850000               2
# Fantasy       7.700000               1
# Film-Noir     8.033333               3
# History       8.000000               1
# Horror        7.806897              29
# Mystery       7.975000              16
# Sci-Fi        7.920000               5
# Thriller      7.680000               5
# Western       8.255556               9

# %%
df.groupby('content_rating')['genre'].aggregate(pd.Series.mode).reset_index()
# Out:
#    content_rating                           genre
# 0        APPROVED                           Drama
# 1               G                       Animation
# 2              GP     [Action, Biography, Comedy]
# 3           NC-17                           Drama
# 4       NOT RATED                           Drama
# 5          PASSED                          Comedy
# 6              PG              [Animation, Drama]
# 7           PG-13                           Drama
# 8               R                           Drama
# 9           TV-MA                           Drama
# 10        UNRATED                           Crime
# 11              X  [Comedy, Crime, Drama, Horror]

# %% [markdown]
# # sort in groupby

# %%
df.groupby('genre',sort=True).aggregate({'star_rating':'mean','content_rating':'count'})
# Out:
#            star_rating  content_rating
# genre
# Action        7.884559             135
# Adventure     7.933333              74
# Animation     7.914516              62
# Biography     7.862338              76
# Comedy        7.822436             156
# Crime         7.916935             124
# Drama         7.902518             278
# Family        7.850000               2
# Fantasy       7.700000               1
# Film-Noir     8.033333               3
# History       8.000000               1
# Horror        7.806897              29
# Mystery       7.975000              16
# Sci-Fi        7.920000               5
# Thriller      7.680000               5
# Western       8.255556               9

# %%
df.groupby('genre',sort=False).aggregate({'star_rating':'mean','content_rating':'count'})
# Out:
#            star_rating  content_rating
# genre
# Crime         7.916935             124
# Action        7.884559             135
# Drama         7.902518             278
# Western       8.255556               9
# Adventure     7.933333              74
# Biography     7.862338              76
# Comedy        7.822436             156
# Animation     7.914516              62
# Mystery       7.975000              16
# Horror        7.806897              29
# Film-Noir     8.033333               3
# Sci-Fi        7.920000               5
# History       8.000000               1
# Thriller      7.680000               5
# Family        7.850000               2
# Fantasy       7.700000               1

# %% [markdown]
# # groups

# %%
df.groupby('genre').groups
# Out:
# {'Action': [3, 11, 12, 19, 20, 36, 37, 43, 44, 45, 75, 80, 82, 96, 100, 113, 118, 123, 129, 135, 138, 152, 163, 173, 177, 194, 196, 198, 235, 239, 240, 248, 261, 268, 276, 281, 296, 301, 312, 327, 349, 354, 366, 380, 385, 388, 391, 401, 403, 409, 411, 420, 433, 434, 437, 440, 452, 455, 469, 470, 488, 491, 502, 509, 515, 517, 529, 531, 532, 533, 534, 539, 552, 563, 567, 568, 570, 573, 581, 586, 591, 598, 610, 613, 619, 623, 633, 649, 653, 661, 671, 675, 683, 684, 685, 686, 691, 699, 701, 707, ...], 'Adventure': [7, 10, 14, 15, 54, 68, 71, 85, 101, 114, 120, 128, 133, 137, 140, 142, 164, 179, 204, 206, 214, 222, 224, 245, 271, 299, 309, 310, 328, 333, 336, 339, 359, 362, 368, 376, 393, 419, 424, 429, 445, 454, 479, 510, 520, 522, 537, 551, 555, 564, 576, 605, 629, 642, 658, 662, 698, 727, 754, 758, 794, 814, 852, 891, 898, 900, 909, 911, 932, 935, 936, 937, 943, 953, 975], 'Animation': [30, 55, 61, 64, 69, 81, 117, 126, 131, 147, 160, 167, 192, 193, 241, 256, 277, 294, 303, 305, 308, 3
# ...

# %%
x = list(df.groupby('genre').groups['Action'])
x
# Out:
# [3,
#  11,
#  12,
#  19,
#  20,
#  36,
#  37,
#  43,
#  44,
#  45,
#  75,
#  80,
#  82,
#  96,
#  100,
#  113,
#  118,
#  123,
#  129,
#  135,
#  138,
#  152,
#  163,
#  173,
#  177,
#  194,
#  196,
#  198,
#  235,
#  239,
#  240,
#  248,
#  261,
#  268,
#  276,
#  281,
#  296,
#  301,
#  312,
#  327,
#  349,
#  354,
#  366,
#  380,
#  385,
#  388,
#  391,
#  401,
#  403,
#  409,
#  411,
#  420,
#  433,
#  434,
#  437,
#  440,
#  452,
#  455,
#  469,
#  470,
#  488,
#  491,
#  502,
#  509,
#  515,
#  517,
#  529,
#  531,
#  532,
#  533,
#  534,
#  539,
#  552,
#  563,
#  567,
#  568,
#  570,
#  573,
#  581,
#  586,
#  591,
#  598,
#  610,
#  613,
#  619,
#  623,
#  633,
#  649,
#  653,
#  661,
#  671,
#  675,
#  683,
#  684,
#  685,
#  686,
#  691,
#  699,
#  701,
#  707,
#  717,
#  722,
#  726,
#  729,
#  733,
#  740,
#  744,
#  745,
#  748,
#  749,
#  753,
#  764,
#  765,
#  767,
#  778,
#  780,
#  787,
#  801,
#  803,
#  809,
#  812,
#  815,
#  832,
#  856,
#  858,
#  871,
# ...

# %%
df.groupby(['genre'],sort=False).groups
# Out:
# {'Crime': [0, 1, 2, 4, 21, 23, 28, 34, 40, 49, 63, 65, 78, 79, 86, 90, 92, 98, 112, 115, 122, 154, 169, 171, 175, 176, 178, 182, 199, 200, 212, 216, 217, 225, 229, 233, 234, 253, 257, 258, 272, 278, 290, 297, 300, 324, 329, 365, 369, 383, 384, 407, 412, 413, 425, 426, 436, 438, 441, 466, 474, 478, 482, 492, 493, 495, 506, 549, 556, 566, 571, 577, 587, 596, 616, 621, 624, 636, 648, 651, 652, 666, 670, 677, 681, 694, 697, 711, 724, 730, 732, 746, 747, 757, 761, 784, 786, 797, 799, 802, ...], 'Action': [3, 11, 12, 19, 20, 36, 37, 43, 44, 45, 75, 80, 82, 96, 100, 113, 118, 123, 129, 135, 138, 152, 163, 173, 177, 194, 196, 198, 235, 239, 240, 248, 261, 268, 276, 281, 296, 301, 312, 327, 349, 354, 366, 380, 385, 388, 391, 401, 403, 409, 411, 420, 433, 434, 437, 440, 452, 455, 469, 470, 488, 491, 502, 509, 515, 517, 529, 531, 532, 533, 534, 539, 552, 563, 567, 568, 570, 573, 581, 586, 591, 598, 610, 613, 619, 623, 633, 649, 653, 661, 671, 675, 683, 684, 685, 686, 691, 699, 701, 707, ...], '
# ...

# %% [markdown]
# # ngroups()

# %%
df.groupby('genre').ngroups
# Out:
# 16

# %%
df.genre.nunique()
# Out:
# 16

# %% [markdown]
# # Size

# %%
df.groupby('genre').size()
# Out:
# genre
# Action       136
# Adventure     75
# Animation     62
# Biography     77
# Comedy       156
# Crime        124
# Drama        278
# Family         2
# Fantasy        1
# Film-Noir      3
# History        1
# Horror        29
# Mystery       16
# Sci-Fi         5
# Thriller       5
# Western        9
# dtype: int64

# %%
df.groupby('genre').agg({'duration':'count'})
# Out:
#            duration
# genre
# Action          136
# Adventure        75
# Animation        62
# Biography        77
# Comedy          156
# Crime           124
# Drama           278
# Family            2
# Fantasy           1
# Film-Noir         3
# History           1
# Horror           29
# Mystery          16
# Sci-Fi            5
# Thriller          5
# Western           9

# %%
df.groupby('genre')['title'].count()
# Out:
# genre
# Action       136
# Adventure     75
# Animation     62
# Biography     77
# Comedy       156
# Crime        124
# Drama        278
# Family         2
# Fantasy        1
# Film-Noir      3
# History        1
# Horror        29
# Mystery       16
# Sci-Fi         5
# Thriller       5
# Western        9
# Name: title, dtype: int64

# %%
df.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

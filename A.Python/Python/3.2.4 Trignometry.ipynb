# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# all numpy trignometric function takes in values in radians only

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
np.sin(np.pi/6)
# Out:
# 0.49999999999999994

# %%
np.cos(np.pi/4)
# Out:
# 0.7071067811865476

# %%
1/np.sqrt(2)
# Out:
# 0.7071067811865475

# %%
np.tan(np.pi)      << tan(pi) is 0
# Out:
# -1.2246467991473532e-16

# %%
cot_90 = np.tan((np.pi/2))**(-1)
cot_90
# Out:
# 6.123233995736766e-17

# %%
6.123233995736766/100000000000000000
# Out:
# 6.123233995736766e-17

# %%
0.0000000000000000061223

# %%
cot_90 = 1/np.tan((np.pi/2))
cot_90
# Out:
# 6.123233995736766e-17

# %% [markdown]
# # degrees to radians

# %% [markdown]
# #### deg2rad()

# %%
np.deg2rad(30)
# Out:
# 0.5235987755982988

# %%
np.pi/6       # (22/7)/6
# Out:
# 0.5235987755982988

# %%
np.sin(0.5235987755982988)
# Out:
# 0.49999999999999994

# %%
np.deg2rad(45),np.pi/4
# Out:
# (0.7853981633974483, 0.7853981633974483)

# %% [markdown]
# #### radians()

# %%
np.radians(30)
# Out:
# 0.5235987755982988

# %%
np.deg2rad(30)
# Out:
# 0.5235987755982988

# %% [markdown]
# # radians to degree

# %% [markdown]
# #### rad2deg()

# %%
np.rad2deg(np.pi/6)
# Out:
# 29.999999999999996

# %%
np.rad2deg(np.pi/4)
# Out:
# 45.0

# %%
np.rad2deg(np.pi)
# Out:
# 180.0

# %% [markdown]
# #### degrees()

# %%
np.degrees(np.pi/6)
# Out:
# 29.999999999999996

# %%
np.degrees(np.pi/4)
# Out:
# 45.0

# %%
np.degrees(np.pi/2)
# Out:
# 90.0

# %%
np.cos(np.radians(45))
# Out:
# 0.7071067811865476

# %%
np.cos(np.pi/4)
# Out:
# 0.7071067811865476

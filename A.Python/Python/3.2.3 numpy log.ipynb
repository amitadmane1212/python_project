# %%
import numpy as np

# %% [markdown]
# # log functions

# %% [markdown]
# ### Natural log >> log to the base e

# %%
np.log(0)
# Out:
# <ipython-input-2-f6e7c0610b57>:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# -inf

# %%
np.log(1)
# Out:
# 0.0

# %%
np.log(np.e)
# Out:
# 1.0

# %%
np.e,np.exp(1)
# Out:
# (2.718281828459045, 2.718281828459045)

# %%
np.log(10)
# Out:
# 2.302585092994046

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### log10 (log 10 to the base any number)

# %%
np.log10(0)
# Out:
# <ipython-input-11-fb8478a94c6a>:1: RuntimeWarning: divide by zero encountered in log10
#   np.log10(0)
# -inf

# %%
np.log10(1)
# Out:
# 0.0

# %%
np.log10(10)
# Out:
# 1.0

# %%
np.log10(100)
# Out:
# 2.0

# %%
np.log10(1000)
# Out:
# 3.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### log2 (log 2 to the base any number)

# %%
np.log2(0)
# Out:
# <ipython-input-17-94b78e711a59>:1: RuntimeWarning: divide by zero encountered in log2
#   np.log2(0)
# -inf

# %%
np.log2(1)
# Out:
# 0.0

# %%
np.log2(2)
# Out:
# 1.0

# %%
np.log2(4)
# Out:
# 2.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.log2(8)
# Out:
# 3.0

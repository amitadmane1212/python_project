# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Emp_Records.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   97 non-null     float64
#  4   Age in Company  99 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            99 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df.isnull()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False           True           False   False
# 1    False       False       False           True            True   False
# 2    False       False       False          False           False   False
# 3    False       False       False           True           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0    True
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False           True           False   False
# 1    False       False       False           True            True   False
# 2    False       False       False          False           False   False
# 3    False       False       False           True           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0    True
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isnull().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     3
# Age in Company    1
# Salary            0
# City              1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     3
# Age in Company    1
# Salary            0
# City              1
# dtype: int64

# %%
df.dropna()       # deletes the entire rows wherever it finds null value
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 7   380086      Carol       59.12           40.0           34.52   60918
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 4        Fremont
# 5      Macksburg
# 6        Atlanta
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 7   380086      Carol       59.12           40.0           34.52   60918
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 4        Fremont
# 5      Macksburg
# 6        Atlanta
# ...

# %%
df = pd.read_csv('Emp_Records.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# # thresold parameter

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.dropna(thresh=6,axis=0)    # at least 6 columns should have non-null values otherwise drop that row.
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# 5      Macksburg
# ...

# %%
df.dropna(thresh=98,axis=1)
# Out:
#     Emp ID First Name  Age in Yrs  Age in Company  Salary          City
# 0   677509       Lois       36.36           13.68  168251           NaN
# 1   940761     Brenda       47.02             NaN   51063     Stonewall
# 2   428945        Joe       54.15            0.98   50155  Michigantown
# 3   408351      Diane       39.67           18.30  180294      Hydetown
# 4   193819   Benjamin       40.31            4.01  117642       Fremont
# ..     ...        ...         ...             ...     ...           ...
# 95  639892       Jose       22.82            1.05  129774        Biloxi
# 96  704709     Harold       32.61            5.93  156194  Carol Stream
# 97  461593     Nicole       52.66           28.53   95673       Detroit
# 98  392491    Theresa       29.60            6.99   51015      Mc Grath
# 99  495141      Tammy       38.38            2.26   93650          Alma
#
# [100 rows x 6 columns]

# %%
df.dropna()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# # Subset Parameter

# %%
df.dropna(subset=['Weight in Kgs'])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 7   380086      Carol       59.12           40.0           34.52   60918
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 4        Fremont
# 5      Macksburg
# 6        Atlanta
# ...

# %%
df.dropna(subset=['City'])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ...

# %%
df.dropna(subset=['City','Age in Company'])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# 5      Macksburg
# ...

# %%
df.dropna(subset=['City','Age in Company'],how='any')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# 5      Macksburg
# ...

# %%
df.dropna(subset=['City','Age in Company'],how='all')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# # finding index of rows having null values

# %%
np.where(df.isna())
# Out:
# (array([0, 0, 1, 1, 3], dtype=int64), array([3, 6, 3, 4, 3], dtype=int64))

# %%
np.where(df['Age in Company'].isnull())
# Out:
# (array([1], dtype=int64),)

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.loc[np.where(df['Age in Company'].isnull())]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 1  940761     Brenda       47.02            NaN             NaN   51063
#
#         City
# 1  Stonewall

# %%
df.loc[np.where(df['Weight in Kgs'].isna())]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
# 3  408351      Diane       39.67            NaN           18.30  180294
#
#         City
# 0        NaN
# 1  Stonewall
# 3   Hydetown

# %%
df[df['Weight in Kgs'].isna()]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
# 3  408351      Diane       39.67            NaN           18.30  180294
#
#         City
# 0        NaN
# 1  Stonewall
# 3   Hydetown

# %% [markdown]
# # dropping rows & columns from the dataframe

# %% [markdown]
# ## dropping columns

# %%
df.drop('Salary',axis=1)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company          City
# 0   677509       Lois       36.36            NaN           13.68           NaN
# 1   940761     Brenda       47.02            NaN             NaN     Stonewall
# 2   428945        Joe       54.15           68.0            0.98  Michigantown
# 3   408351      Diane       39.67            NaN           18.30      Hydetown
# 4   193819   Benjamin       40.31           58.0            4.01       Fremont
# ..     ...        ...         ...            ...             ...           ...
# 95  639892       Jose       22.82           89.0            1.05        Biloxi
# 96  704709     Harold       32.61           77.0            5.93  Carol Stream
# 97  461593     Nicole       52.66           60.0           28.53       Detroit
# 98  392491    Theresa       29.60           57.0            6.99      Mc Grath
# 99  495141      Tammy       38.38           55.0            2.26          Alma
#
# [100 rows x 6 columns]

# %%
df.drop(['Salary','Emp ID'],axis=1)
# Out:
#    First Name  Age in Yrs  Weight in Kgs  Age in Company          City
# 0        Lois       36.36            NaN           13.68           NaN
# 1      Brenda       47.02            NaN             NaN     Stonewall
# 2         Joe       54.15           68.0            0.98  Michigantown
# 3       Diane       39.67            NaN           18.30      Hydetown
# 4    Benjamin       40.31           58.0            4.01       Fremont
# ..        ...         ...            ...             ...           ...
# 95       Jose       22.82           89.0            1.05        Biloxi
# 96     Harold       32.61           77.0            5.93  Carol Stream
# 97     Nicole       52.66           60.0           28.53       Detroit
# 98    Theresa       29.60           57.0            6.99      Mc Grath
# 99      Tammy       38.38           55.0            2.26          Alma
#
# [100 rows x 5 columns]

# %% [markdown]
# ## dropping of rows

# %%
df.drop([4],axis=0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 5   499687    Patrick       34.86           58.0           12.02   72305
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.drop([0,1],axis=0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# 5      Macksburg
# ...

# %%
df[df['Weight in Kgs']<50].index
# Out:
# Int64Index([ 7,  8, 14, 15, 28, 29, 30, 39, 40, 41, 47, 49, 51, 55, 56, 57, 58,
#             60, 69, 75, 76, 80, 88],
#            dtype='int64')

# %%
df.drop(df[df['Weight in Kgs']<50].index,axis=0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.to_csv('Null_Treated.csv')

# %%
df.to_json('Null_Treated.json')

# %%
df.to_excel('Null_Treated.xlsx')

# %%
d1 = df.to_dict()
d1
# Out:
# {'Emp ID': {0: 677509,
#   1: 940761,
#   2: 428945,
#   3: 408351,
#   4: 193819,
#   5: 499687,
#   6: 539712,
#   7: 380086,
#   8: 477616,
#   9: 162402,
#   10: 231469,
#   11: 153989,
#   12: 386158,
#   13: 301576,
#   14: 441771,
#   15: 528509,
#   16: 912990,
#   17: 214352,
#   18: 890290,
#   19: 622406,
#   20: 979607,
#   21: 969580,
#   22: 426038,
#   23: 388642,
#   24: 560455,
#   25: 477253,
#   26: 263480,
#   27: 683826,
#   28: 474599,
#   29: 335732,
#   30: 329752,
#   31: 893212,
#   32: 621833,
#   33: 456747,
#   34: 278556,
#   35: 333476,
#   36: 218791,
#   37: 134841,
#   38: 726264,
#   39: 766610,
#   40: 923947,
#   41: 227922,
#   42: 265813,
#   43: 247137,
#   44: 407061,
#   45: 226714,
#   46: 702813,
#   47: 524896,
#   48: 363065,
#   49: 879753,
#   50: 958326,
#   51: 447813,
#   52: 525955,
#   53: 818384,
#   54: 971640,
#   55: 253573,
#   56: 904898,
#   57: 515103,
#   58: 491943,
#   59: 750173,
#   60: 687017,
#   61: 241882,
# ...

# %%
### dropping values

# counting null values in columns
df.isnull()
df.isna()
df.isnull().sum()
df.isna().sum()

# dropping null values
df.dropna(thresh=,subset=,axis=,inplace=,how=)

# dropping rows or columns
df.drop()

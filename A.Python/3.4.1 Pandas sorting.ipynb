# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Emp_Records.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   97 non-null     float64
#  4   Age in Company  99 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            99 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df.shape
# Out:
# (100, 7)

# %%
df.describe()
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000      97.000000       99.000000     100.000000
# mean   547652.10000   39.238700      58.113402        8.978081  119738.090000
# std    257664.16679   12.066252      12.460668        8.701416   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.045000   83979.750000
# 50%    497414.00000   37.595000      56.000000        5.930000  118049.500000
# 75%    766040.00000   49.900000      62.000000       13.845000  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['Emp ID', 'First Name', 'Age in Yrs', 'Weight in Kgs', 'Age in Company',
#         'Salary', 'City'],
#        dtype='object')]

# %%
df.size
# Out:
# 700

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 99  495141      Tammy       38.38           55.0            2.26   93650
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 96  704709     Harold       32.61           77.0            5.93  156194
# 95  639892       Jose       22.82           89.0            1.05  129774
# ..     ...        ...         ...            ...             ...     ...
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 3   408351      Diane       39.67            NaN           18.30  180294
# 2   428945        Joe       54.15           68.0            0.98   50155
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 0   677509       Lois       36.36            NaN           13.68  168251
#
#             City
# 99          Alma
# 98      Mc Grath
# 97       Detroit
# 96  Carol Stream
# ...

# %%
df.set_index('Emp ID',inplace=True)      # setting any column of df as index

# %%
df
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 677509       Lois       36.36            NaN           13.68  168251
# 940761     Brenda       47.02            NaN             NaN   51063
# 428945        Joe       54.15           68.0            0.98   50155
# 408351      Diane       39.67            NaN           18.30  180294
# 193819   Benjamin       40.31           58.0            4.01  117642
# ...           ...         ...            ...             ...     ...
# 639892       Jose       22.82           89.0            1.05  129774
# 704709     Harold       32.61           77.0            5.93  156194
# 461593     Nicole       52.66           60.0           28.53   95673
# 392491    Theresa       29.60           57.0            6.99   51015
# 495141      Tammy       38.38           55.0            2.26   93650
#
#                 City
# Emp ID
# 677509           NaN
# 940761     Stonewall
# 428945  Michigantown
# 408351      Hydetown
# ...

# %%
df.sort_index(axis=0)         # sorting the rows of the dataframe
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 134841      Donna       33.89           57.0            4.03  129836
# 153989       Jack       22.21           61.0            0.56   82965
# 158666    Rebecca       56.00           55.0           34.32  160043
# 162402      Diana       29.73           60.0            3.44   43010
# 183071     Andrea       32.08           52.0            7.28   54179
# ...           ...         ...            ...             ...     ...
# 958326      Larry       28.76           75.0            0.43   97904
# 969580    Matthew       23.77           56.0            1.47   52237
# 969964     Janice       37.57           56.0            0.93  147641
# 971640   Clarence       56.66           64.0            8.58  165272
# 979607      Carol       22.64           56.0            1.26   93967
#
#                            City
# Emp ID
# 134841                     Lima
# 153989                Las Vegas
# ...

# %%
df.sort_index(axis=1)       # sorting the columns of the dataframe
# Out:
#         Age in Company  Age in Yrs          City First Name  Salary  \
# Emp ID
# 677509           13.68       36.36           NaN       Lois  168251
# 940761             NaN       47.02     Stonewall     Brenda   51063
# 428945            0.98       54.15  Michigantown        Joe   50155
# 408351           18.30       39.67      Hydetown      Diane  180294
# 193819            4.01       40.31       Fremont   Benjamin  117642
# ...                ...         ...           ...        ...     ...
# 639892            1.05       22.82        Biloxi       Jose  129774
# 704709            5.93       32.61  Carol Stream     Harold  156194
# 461593           28.53       52.66       Detroit     Nicole   95673
# 392491            6.99       29.60      Mc Grath    Theresa   51015
# 495141            2.26       38.38          Alma      Tammy   93650
#
#         Weight in Kgs
# Emp ID
# 677509            NaN
# 940761            NaN
# 428945           68.0
# 408351            NaN
# ...

# %%
df
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 677509       Lois       36.36            NaN           13.68  168251
# 940761     Brenda       47.02            NaN             NaN   51063
# 428945        Joe       54.15           68.0            0.98   50155
# 408351      Diane       39.67            NaN           18.30  180294
# 193819   Benjamin       40.31           58.0            4.01  117642
# ...           ...         ...            ...             ...     ...
# 639892       Jose       22.82           89.0            1.05  129774
# 704709     Harold       32.61           77.0            5.93  156194
# 461593     Nicole       52.66           60.0           28.53   95673
# 392491    Theresa       29.60           57.0            6.99   51015
# 495141      Tammy       38.38           55.0            2.26   93650
#
#                 City
# Emp ID
# 677509           NaN
# 940761     Stonewall
# 428945  Michigantown
# 408351      Hydetown
# ...

# %%
df.T             # Transpose of the dataframe. (rows becomes columns & columns into rows)
# Out:
#                     0          1             2         3         4   \
# Emp ID          677509     940761        428945    408351    193819
# First Name        Lois     Brenda           Joe     Diane  Benjamin
# Age in Yrs       36.36      47.02         54.15     39.67     40.31
# Weight in Kgs      NaN        NaN          68.0       NaN      58.0
# Age in Company   13.68        NaN          0.98      18.3      4.01
# Salary          168251      51063         50155    180294    117642
# City               NaN  Stonewall  Michigantown  Hydetown   Fremont
#
#                        5        6            7        8               9   ...  \
# Emp ID             499687   539712       380086   477616          162402  ...
# First Name        Patrick    Nancy        Carol  Frances           Diana  ...
# Age in Yrs          34.86    22.14        59.12    58.18           29.73  ...
# Weight in Kgs        58.0     50.0         40.0     42.0            60.0  ...
# ...

# %%
(df.T).sort_index(axis=0).T
# Out:
#    Age in Company Age in Yrs          City  Emp ID First Name  Salary  \
# 0           13.68      36.36           NaN  677509       Lois  168251
# 1             NaN      47.02     Stonewall  940761     Brenda   51063
# 2            0.98      54.15  Michigantown  428945        Joe   50155
# 3            18.3      39.67      Hydetown  408351      Diane  180294
# 4            4.01      40.31       Fremont  193819   Benjamin  117642
# ..            ...        ...           ...     ...        ...     ...
# 95           1.05      22.82        Biloxi  639892       Jose  129774
# 96           5.93      32.61  Carol Stream  704709     Harold  156194
# 97          28.53      52.66       Detroit  461593     Nicole   95673
# 98           6.99       29.6      Mc Grath  392491    Theresa   51015
# 99           2.26      38.38          Alma  495141      Tammy   93650
#
#    Weight in Kgs
# 0            NaN
# 1            NaN
# 2           68.0
# 3            NaN
# 4           58.0
# ...

# %%
df.reset_index(inplace=True)      # setting up default index columns

# %% [markdown]
# # sort any columns()

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_values('Age in Yrs',ascending=True)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 13  301576      Wayne       21.10           87.0            0.02   92758
# 49  879753     Pamela       21.30           47.0            0.13  149262
# 59  750173    Antonio       21.93           82.0            0.24  181646
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 11  153989       Jack       22.21           61.0            0.56   82965
# ..     ...        ...         ...            ...             ...     ...
# 74  528673       Paul       58.43           60.0           22.10  145235
# 7   380086      Carol       59.12           40.0           34.52   60918
# 57  515103       Anne       59.27           48.0           14.01  114426
# 24  560455    Carolyn       59.42           53.0           16.08   42005
# 14  441771     Cheryl       59.47           47.0           26.69   92220
#
#            City
# 13        Maida
# 49       Banner
# 59     Mc Calla
# 6       Atlanta
# ...

# %%
df.sort_values(['Weight in Kgs','Salary'],ascending=True)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 7   380086      Carol       59.12           40.0           34.52   60918
# 75  765850      Linda       25.96           40.0            0.20  113256
# 41  227922     Amanda       35.02           40.0           10.28  114257
# 47  524896       Judy       56.38           40.0            5.59  133332
# 28  474599      Maria       42.39           41.0           18.84   48944
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 38  726264       Carl       43.63           90.0           10.14  162159
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 0   677509       Lois       36.36            NaN           13.68  168251
# 3   408351      Diane       39.67            NaN           18.30  180294
#
#             City
# 7    Blanchester
# 75        Albion
# 41  Lake Charles
# 47        Topeka
# ...

# %%
df.sort_values(['Weight in Kgs','Salary'],ascending=[True,False])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 47  524896       Judy       56.38           40.0            5.59  133332
# 41  227922     Amanda       35.02           40.0           10.28  114257
# 75  765850      Linda       25.96           40.0            0.20  113256
# 7   380086      Carol       59.12           40.0           34.52   60918
# 51  447813        Ann       28.23           41.0            3.69  130014
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 38  726264       Carl       43.63           90.0           10.14  162159
# 3   408351      Diane       39.67            NaN           18.30  180294
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
#
#             City
# 47        Topeka
# 41  Lake Charles
# 75        Albion
# 7    Blanchester
# ...

# %%
df.sort_values('City',ascending=False)
# Out:
#     Emp ID   First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 38  726264         Carl       43.63           90.0           10.14  162159
# 23  388642         Ruby       37.27           59.0            3.91  160623
# 65  917395  Christopher       57.37           62.0           19.73  190765
# 85  476433      Lillian       42.79           55.0           17.65  149878
# 92  969964       Janice       37.57           56.0            0.93  147641
# ..     ...          ...         ...            ...             ...     ...
# 56  904898          Ann       24.61           44.0            0.45  182521
# 99  495141        Tammy       38.38           55.0            2.26   93650
# 67  316110       Jeremy       52.51           52.0           11.33  178847
# 75  765850        Linda       25.96           40.0            0.20  113256
# 0   677509         Lois       36.36            NaN           13.68  168251
#
#                        City
# 38                   Wright
# ...

# %%
dummy = pd.DataFrame(data = np.random.randint(10,20,20).reshape(5,4),columns=list('ABCD'),index=list('abcde'))

dummy
# Out:
#     A   B   C   D
# a  13  14  11  14
# b  18  18  11  16
# c  19  11  13  12
# d  18  10  14  13
# e  12  10  18  19

# %%
dummy.sort_values(by = 'a',axis=1)
# Out:
#     C   A   B   D
# a  11  13  14  14
# b  11  18  18  16
# c  13  19  11  12
# d  14  18  10  13
# e  18  12  10  19

# %%
dummy.sort_values(['a','b'],axis=1,ascending=[True,True])
# Out:
#     C   A   D   B
# a  11  13  14  14
# b  11  18  16  18
# c  13  19  12  11
# d  14  18  13  10
# e  18  12  19  10

# %%
dummy.sort_values('c',ascending=False, axis=1)
# Out:
#     A   C   D   B
# a  13  11  14  14
# b  18  11  16  18
# c  19  13  12  11
# d  18  14  13  10
# e  12  18  19  10

# %% [markdown]
# # setting & resetting a columns into dataframe

# %%
dummy
# Out:
#     A   B   C   D
# a  13  14  11  14
# b  18  18  11  16
# c  19  11  13  12
# d  18  10  14  13
# e  12  10  18  19

# %%
dummy = dummy.set_index('D')
dummy
# Out:
#      A   B   C
# D
# 14  13  14  11
# 16  18  18  11
# 12  19  11  13
# 13  18  10  14
# 19  12  10  18

# %%
dummy.reset_index(inplace=True)

# %%
dummy
# Out:
#     D   A   B   C
# 0  14  13  14  11
# 1  16  18  18  11
# 2  12  19  11  13
# 3  13  18  10  14
# 4  19  12  10  18

# %%
dummy.set_index('A',inplace=True)
dummy
# Out:
#      D   B   C
# A
# 13  14  14  11
# 18  16  18  11
# 19  12  11  13
# 18  13  10  14
# 12  19  10  18

# %%
dummy.reset_index(drop=True,inplace=True)
dummy
# Out:
#     D   B   C
# 0  14  14  11
# 1  16  18  11
# 2  12  11  13
# 3  13  10  14
# 4  19  10  18

# %% [markdown]
# # changing the sequence of columns

# %%
dummy = dummy[['B','C','D']]
dummy
# Out:
#     B   C   D
# 0  14  11  14
# 1  18  11  16
# 2  11  13  12
# 3  10  14  13
# 4  10  18  19
